# %% [markdown]
# <img src="https://datasciencedegree.wisconsin.edu/wp-content/themes/data-gulp/images/logo.svg" width="300">

# %% [markdown]
#  # <center>DS 710 - Lesson 1</center>

# %% [markdown]
# This notebook will provide some introductory practice with Jupyter notebooks, and also give you a chance to use several basic commands in Python.
#
# References for the material in this notebook include
# * Chapters 1 and 2 of *Python for Data Analysis*,
# * <a href="https://www.learnpython.org/">learnpython.org</a>, and
# * the <a href="https://docs.python.org/3/">official Python documentation</a> (this is one of the best resources for Python -- use it!).

# %% [markdown]
# ---
# ### Exponentiation & running code
#
# In Python, `**` indicates exponentiation. 🧠 Predict what the code in the cell below will output, then run the code by clicking inside the cell and using `Ctrl+Enter` or `Shift+Enter`.

# %%
2**(2+2)
# Out:
# 16

# %% [markdown]
# 🧠 Now, write (and run) code in the cell below to find the value of $5^6$.

# %%
5**6
# Out:
# 15625

# %% [markdown]
# ---
#
# ### The modulo operator & adding cells
#
# The symbol `%` indicates the modulo symbol in Python (see e.g. the <a href="https://docs.python.org/3/reference/expressions.html#binary-arithmetic-operations">Python documentation on binary arithmetic operations</a>).
#
# 🧠 Create two cells below this one by clicking once on this cell to highlight it, and typing `b` (or `B`) twice. In these new cells, write code to determine $17 \ (\text{mod } 3)$ and $13 \ (\text{mod } 2)$.

# %%
17%3
# Out:
# 2

# %%
13%2
# Out:
# 1

# %% [markdown]
# ---
#
# ### Variables & Booleans

# %% [markdown]
# A single equals sign assigns a value to a variable: for example, `x=6` stores the value $6$ in the variable $x$. We can also test if a particular variable or expression is equal to another value by using a double equals sign. For example, `x==6` is a Boolean expression that returns `True` if $x$ is $6$, and `False` otherwise.
#
# 🧠 Predict what the following code will output, then check your prediction.

# %%
x=213
y=x%2
y**3==1
# Out:
# True

# %% [markdown]
# ---
#
# ### Exploring `^`
#
# To discover the meaning of `^` in Python, 🧠 run the code in the cells below.

# %%
True^True
# Out:
# False

# %%
True^False
# Out:
# True

# %%
False^False
# Out:
# False

# %%
False^True
# Out:
# True

# %% [markdown]
# 🧠 Using what you learned above, predict the output of the code in the cell below, then run it.

# %%
(2 == 7) ^ (2**3 == 8)
#False ^ True
# Out:
# True

# %% [markdown]
# 🧠 In a cell you insert below, write new code (i.e. different from any you have written or run thus far in this notebook) using `^` (and any numbers and other operators you wish) that will return `False`.

# %%
10^2 == 5^2
# Out:
# False

# %% [markdown]
# ---
#
# ### Some string basics
#
# The variable `r`, defined below, is a string literal. It may also be defined using double quotes: `r="a string"`.

# %%
r='a string'
print(r)
# Out:
# a string

# %% [markdown]
# We may manipulate strings in a number of ways. Concatenation, accomplished using `+`, is shown below. Other string operations can be explored <a href="https://www.learnpython.org/en/Basic_String_Operations">here</a> or <a href="https://docs.python.org/3/tutorial/introduction.html?highlight=basic%20string%20concatenate#strings">here</a>.

# %%
'This is also '+r
# Out:
# 'This is also a string'

# %% [markdown]
# An f-string (formatted string literal) is a string literal that may contain curly braces indicating replacement fields. 🧠 Predict what the code below will output, then run it to check your thinking. Further information on formatting strings can be found <a href="https://docs.python.org/3/reference/lexical_analysis.html#f-strings">here</a> or <a href="https://www.learnpython.org/en/String_Formatting">here</a>.

# %%
print(f"'A string' is {r}")
# Out:
# 'A string' is a string

# %% [markdown]
# ---

# %%
x="They"

# %%
print(f"{x} say 'hello'")
# Out:
# They say 'hello'

# %% [markdown]
# ## When you're done
#
# After completing the guided practice above, log onto Canvas to complete Quiz 1. You may wish to keep this notebook open while you work.
