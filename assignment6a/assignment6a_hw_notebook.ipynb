# %%
# Import Packages
import pandas as pd

# %%
# Task 1
# Subtask 1.1
# Load the data
salary_df = pd.read_excel("2021_Salary Statistics by Employee.xlsx")
salary_df.head()
# Out:
#                          Name    Sub Department Empl Class Code Pay Basis  \
# 0              BECKER, JANE A  ACADEMIC AFFAIRS              CP         H
# 1          CASE, JASMINE LEAH  ACADEMIC AFFAIRS              AS         A
# 2     ROZOWSKI, CASEY MATTHEW  ACADEMIC AFFAIRS              LI         A
# 3  JAMELSKE, STEPHANIE PASCOE  ACADEMIC AFFAIRS              LI         A
# 4             HOFFMAN, MARY F  ACADEMIC AFFAIRS              LI         A
#
#    Job FTE  Years in Job              Job Title  \
# 0      1.0      7.704110   UNIV EXEC STAFF ASST
# 1      1.0      0.027397     ADMIN PROGRAM SPEC
# 2      1.0      1.120548  DIR, UNSPECIFIED (10)
# 3      1.0     16.668493        ADMIN OFFICER/M
# 4      1.0      1.205479  ASSOC VICE CHANCELLOR
#
#                     Working Title  Comp Rate  Annual Salary
# 0            UNIV EXEC STAFF ASST      27.64        57491.2
# 1    SPEC-STUDENT RET/ ENGAGE LRN   62000.00        62000.0
# 2  DIR MGMT, ANALYTICS, REPORTING  100000.00       100000.0
# 3                  BUDGET OFFICER  100444.00       100444.0
# 4   INTERIM ASSOC VICE CHANCELLOR  144840.00       144840.0

# %%
salary_df.shape
salary_df.columns
# Out:
# Index(['Name', 'Sub Department', 'Empl Class Code', 'Pay Basis', 'Job FTE',
#        'Years in Job', 'Job Title', 'Working Title', 'Comp Rate',
#        'Annual Salary'],
#       dtype='str')

# %%
longest_years_department = salary_df.loc[salary_df['Years in Job'].idxmax()]['Sub Department']
print(longest_years_department)
# Out:
# GEOGRAPHY & ANTHROPOLOGY

# %%
salary_df[salary_df['Sub Department'] == longest_years_department]['Annual Salary'].max()
# Out:
# np.float64(82468.0)
